# %%
import importlib
import retrieval.rag_pipeline
importlib.reload(retrieval.rag_pipeline)

from retrieval.rag_pipeline import RAGPipeline

rag = RAGPipeline()
result = rag.query("What technologies did the candidate use?")

# --- Cited answer with inline [1][2] markers ---
print("📄 CITED ANSWER:")
print(result["cited_answer"])

# --- Per-sentence breakdown ---
print("\n🔍 SENTENCE-BY-SENTENCE BREAKDOWN:")
for i, s in enumerate(result["cited_sentences"]):
    verdict_icon = "✅" if s["verdict"] == "SUPPORTED" else "⚠️" if s["verdict"] == "WEAK" else "❌"
    print(f"\n  Sentence {i+1}: {verdict_icon} {s['verdict']}")
    print(f"  Text: {s['sentence'][:80]}...")
    print(f"  Best match: [{s['citation_index']}] {s['citation_source']} Page {s['citation_page']}")
    print(f"  Similarity: {s['similarity']}")

# --- Sources list ---
print("\n📚 SOURCES:")
print(result["sources_list"])
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# ✅ VectorStore ready — collection: truthguard_docs
#    Documents in store: 16
# ✅ CitationMapper ready — using BAAI/bge-small-en-v1.5
# ✅ RAG Pipeline ready — using phi3:mini
# 📄 CITED ANSWER:
# The candidate used a variety of technologies including Python, Java, React.js, Node.js, Databricks MLflow, Delta Tables with PySpark, FastAPI, Uvicorn, Axios for HTTP requests in JavaScript (or TypeScript), and various machine learning libraries such as scikit-learn, pandas, numpy. [5]
#
# 🔍 SENTENCE-BY-SENTENCE BREAKDOWN:
#
#   Sentence 1: ✅ SUPPORTED
#   Text: The candidate used a variety of technologies including Python, Java, React.js, N...
#   Best match: [5] Laabh_Gupta.pdf Page 1
#   Similarity: 0.7879
#
# 📚 SOURCES:
# ...
